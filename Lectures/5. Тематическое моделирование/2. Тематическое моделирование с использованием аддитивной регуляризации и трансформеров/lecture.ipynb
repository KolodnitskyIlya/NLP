# %% [markdown]
# # Тематическое моделирование с использованием аддитивной регуляризации и трансформеров

# %% [markdown]
# ## Аддитивная регуляризация (BigARTM)
#
# > Библиотека BigARTM не поддерживает Python >3.8. Это значит, что запустить ноутбук с примерами в Colab вы **не сможете** (без костылей). Рассмотрите использование локального Jupyter Notebook
#
# > При работе с ОС Windows [следуйте этой инструкции](https://bigartm.readthedocs.io/en/stable/installation/windows.html) по установке BigARTM. Когда дойдете до пункта  `Download the latest package from...` — [скачайте архив по ссылке](https://github.com/bigartm/bigartm/releases/download/v0.9.0/BigARTM_v0.9.0_win64.7z)
#
# [Ноутбук](https://colab.research.google.com/drive/1ZPdadYiIBeZArurohvq68eWD7PO5oC6f?usp=sharing)

# %% [markdown]
# ## Трансформеры (BERTopic)
#
# > API рассматриваемых библиотек могут отличаться от актуальных
#
# [Ноутбук](https://colab.research.google.com/drive/1Odv2S88WufRVZQex23l2mX7ZnCv9kwTZ?usp=sharing)
